# %% [markdown]
# # Project by Shweta Purushothaman
# # Batch no.: WS103806
# # Post Graduate Program in Data Science by CareerEra

# %% [markdown]
# # Ecommerce Capstone Project
#
# - Project background and context
#     - An international e-commerce company which sells electronic products wants to discover key insights from their customer database. They want to use some of the most advanced machine learning techniques to study their customers.

# %% [markdown]
# # Step 1: Perform Exploratory Data Analysis (EDA) on the Dataset
#
# Exploratory Data Analysis (EDA) refers to the method of studying and exploring record sets to apprehend their predominant traits, discover patterns, locate outliers, and identify relationships between variables. EDA is normally carried out as a preliminary step before undertaking extra formal statistical analyses or modeling.
#
# Steps to perform EDA are as follows:
#
# - Perform data loading and basic data exploration. (No. of rows and columns, shape)
# - Conduct descriptive statistics on the dataset. (count, mean, standard deviation, min, max, 25%, 50%, 75% percentile, datatype)
# - Identify and handle missing values in the dataset. (Nan/Null values)
# - Identify and handle duplicate records in the dataset. (Dropping same records)
# - Perform feature engineering by creating a new column. (Adjustments in the dataset for meaningful insights)
# - Analyze the correlation between the data fields. (Discover relationships and dependencies between variables)
# - Visualize the distribution of passenger ages. (Visualize dataset using different scenarios)
# - Calculate skewness(measure of symmetry) and curtosis(heavy-tailed or light-tailed)
# - Treat outlier (Drastically deviating factors)
# - Conduct a hypothesis test (Addition evaluation for model building)

# %%
#Importing all the required packages/libraries for reading the dataset and for visualization

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
#Loading dataset and displaying the first 5 rows
#(We are displaying first 5 rows inorder to visualize the row and columns and the input values)

data = pd.read_csv("E_Commerce.csv")
data
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls
# 0          1               D           Flight                    4  \
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases
# 0                    2                  177                3  \
# ...

# %%
#Checking the total number of columns and rows
#(Total no. of rows and cols will help us know the size of the dataset on which we're working)

data.shape
# Out:
# (10999, 12)

# %%
#Displaying statistics regarding the data
#(For all the continuous variable the count, mean, standard deviation, min, max, 25%, 50%, 75% percentile will be shown)
#Percentile : how many of the values are less than the given percentile.

data.describe()
# Out:
#                 ID  Customer_care_calls  Customer_rating  Cost_of_the_Product
# count  10999.00000         10999.000000     10999.000000         10999.000000  \
# mean    5500.00000             4.054459         2.990545           210.196836
# std     3175.28214             1.141490         1.413603            48.063272
# min        1.00000             2.000000         1.000000            96.000000
# 25%     2750.50000             3.000000         2.000000           169.000000
# 50%     5500.00000             4.000000         3.000000           214.000000
# 75%     8249.50000             5.000000         4.000000           251.000000
# max    10999.00000             7.000000         5.000000           310.000000
#
#        Prior_purchases  Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# count     10999.000000      10999.000000   10999.000000         10999.000000
# mean          3.567597         13.373216    3634.016729             0.596691
# ...

# %%
#Checking for any null values

data.isna().sum()

#For the dataset there are no missing/NaN/Null values
# Out:
# ID                     0
# Warehouse_block        0
# Mode_of_Shipment       0
# Customer_care_calls    0
# Customer_rating        0
# Cost_of_the_Product    0
# Prior_purchases        0
# Product_importance     0
# Gender                 0
# Discount_offered       0
# Weight_in_gms          0
# Reached.on.Time_Y.N    0
# dtype: int64

# %%
# Identify and handle duplicate records in the dataset. How many duplicate records are present?

print("Before Dropping the duplicate records:")
data
# Out:
# Before Dropping the duplicate records:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls
# 0          1               D           Flight                    4  \
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases
# ...

# %%
# drop duplicate rows

drop_data = data.drop_duplicates(keep=False, ignore_index=True)
print("After Dropping the duplicate records:")
drop_data
# Out:
# After Dropping the duplicate records:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls
# 0          1               D           Flight                    4  \
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases
# ...

# %% [markdown]
# We can figure out, before and after dropping the duplicate records, the shape i.e; the number of rows and columns are same (10999 rows × 12 columns)
# Hence we can conclude there are no duplicate records in our dataset

# %%
#Checking the datatype for each column (we can also use data.info())

data.dtypes
# Out:
# ID                      int64
# Warehouse_block        object
# Mode_of_Shipment       object
# Customer_care_calls     int64
# Customer_rating         int64
# Cost_of_the_Product     int64
# Prior_purchases         int64
# Product_importance     object
# Gender                 object
# Discount_offered        int64
# Weight_in_gms           int64
# Reached.on.Time_Y.N     int64
# dtype: object

# %% [markdown]
# From the above information we can figure out there are,
#
# - Continuous data: ID, Customer_care_calls, Customer_rating, Cost_of_the_Product, Prior_purchases, Discount_offered, Weight_in_gms, Reached.on.Time_Y.N
# - Categorical data: Warehouse_block, Mode_of_Shipment, Product_importance, Gender
#
# For our model building we need Warehouse_block, Mode_of_Shipment, Product_importance columns for the analysis.
# So let's convert these categorical data into numerical data

# %%
#Displaying the fields present in each column to be converted

print("Warehouse_block: ", data['Warehouse_block'].unique())
print("Mode_of_Shipment: ", data['Mode_of_Shipment'].unique())
print("Product_importance: ", data['Product_importance'].unique())
# Out:
# Warehouse_block:  ['D' 'F' 'A' 'B' 'C']
# Mode_of_Shipment:  ['Flight' 'Ship' 'Road']
# Product_importance:  ['low' 'medium' 'high']

# %%
# Replacing the values (We can also use "LabelEncoder" which is a sklearn class, but I'm using replace method inorder to assign values of my choice)

data['Warehouse_block'].replace(['A', 'B', 'C', 'D', 'F'],
                        [1,2,3,4,5], inplace=True)
data['Mode_of_Shipment'].replace(['Flight', 'Ship', 'Road'],
                        [1,2,3], inplace=True)
data['Product_importance'].replace(['low', 'medium', 'high'],
                        [1,2,3], inplace=True)

data.head()
# Out:
#    ID  Warehouse_block  Mode_of_Shipment  Customer_care_calls
# 0   1                4                 1                    4  \
# 1   2                5                 1                    4
# 2   3                1                 1                    2
# 3   4                2                 1                    3
# 4   5                3                 1                    2
#
#    Customer_rating  Cost_of_the_Product  Prior_purchases  Product_importance
# 0                2                  177                3                   1  \
# 1                5                  216                2                   1
# 2                2                  183                4                   1
# 3                3                  176                4                   2
# 4                2                  184                3                   2
#
#   Gender  Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# 0      F                44           1233                    1
# ...

# %%
#Dropping columns which give us no relevant information for analysis

data.drop(['ID','Gender'], 
        inplace = True, axis = 1)

data.head()
# Out:
#    Warehouse_block  Mode_of_Shipment  Customer_care_calls  Customer_rating
# 0                4                 1                    4                2  \
# 1                5                 1                    4                5
# 2                1                 1                    2                2
# 3                2                 1                    3                3
# 4                3                 1                    2                2
#
#    Cost_of_the_Product  Prior_purchases  Product_importance  Discount_offered
# 0                  177                3                   1                44  \
# 1                  216                2                   1                59
# 2                  183                4                   1                48
# 3                  176                4                   2                10
# 4                  184                3                   2                46
#
#    Weight_in_gms  Reached.on.Time_Y.N
# ...

# %%
#Let's now check the correlation of the different variables to check for multi-colinearity

plt.figure(figsize = (15,15))
sns.heatmap(data.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# As we see above, there is a high correlation b/w
#
# - Weight_in_gms & Discount_offered
# - Weight_in_gms & Customer_care_calls
# - Weight_in_gms & Reached.on.Time_Y.N
# - Weight_in_gms & Prior_purchases

# %% [markdown]
# Let's do some visualization for the dataset

# %%
#Let's visualize the mode of shipments

data['Mode_of_Shipment'] = data['Mode_of_Shipment'].map({1: 'Flight', 2: 'Ship', 3: 'Road'})
sns.countplot(x=data['Mode_of_Shipment'],data=data)
plt.show()

# %% [markdown]
# By looking at the above bar garph we can conclude,
# - The maximum shipment was made using ships, secondly for flight and the minimum mode is for road.

# %%
# Countplot for each mode of shipment with number of call made to the customer service and the customer ratings

sns.catplot(x ='Customer_care_calls', hue ='Customer_rating',
kind ='count', col ='Mode_of_Shipment', data = data)

# %% [markdown]
# From the above graph we can figure out,
# - for all the modes of shipment the majority of number of calls made to the customer service was 3,4,5.
# - for Flight shipment the frequency of high no. of call was 4 and the highest ratings given was 1.
# - for Ship shipment the frequency of high no. of call was 4 and the highest ratings given was 3.
# - for Road shipment the frequency of high no. of call was 4 and the highest ratings given was 3, 4, 5.

# %%
#Let's visualize Product importance

data['Product_importance'] = data['Product_importance'].map({1: 'Low', 2: 'Medium', 3: 'High'})
sns.countplot(x=data['Product_importance'],data=data)
# Out:
# <Axes: xlabel='Product_importance', ylabel='count'>

# %% [markdown]
# By looking at the above bar garph we can conclude,
# - The maximum count for Product importance is for low, secondly for medium and the minimum count is for high importance

# %%
# Countplot for each product importance with number of call made to the customer service and the customer ratings

sns.catplot(x ='Customer_care_calls', hue ='Customer_rating',
kind ='count', col ='Product_importance', data = data)

# %% [markdown]
# From the above graph we can figure out,
# - for all the product importance entities the majority of number of calls made to the customer service was 3,4.
# - for low importance items the frequency of high no. of call was 4 and the highest ratings given was 2.
# - for medium importance items the frequency of high no. of call was 4 and the highest ratings given was 3.
# - for high importance items the frequency of high no. of call was 3 and the highest ratings given was 4.

# %%
# let's visualize the Customer Rating against product reached on time.

ratings = data.groupby('Customer_rating')['Reached.on.Time_Y.N'].value_counts().unstack()

ratings.plot(kind='bar')

plt.legend(('Reached', 'Unreached'), bbox_to_anchor=(1.02, 1), loc='upper left')
plt.title('Customer rating by arrival of product')
plt.xlabel('Customer ratings')
plt.ylabel('Count')
plt.xticks(rotation=0)

plt.show()

# %% [markdown]
# From the below graph we can observe,
# - A mix of ratings given for reached and unreached items.
# - For all the ratings the unreached counts is between 1200-1400 and the reached counts is between 800-1000
# - The highest unreached items had the rating as 3
# - The highest reached items had the rating as 1

# %%
#Create a bar chart that shows different product importance grouped by customer ratings.

Class = data.groupby('Customer_rating')['Product_importance'].value_counts().unstack()

plt.figure(figsize=(5,5))
Class.plot(kind='bar')

plt.legend(('Low', 'Medium', 'High'), bbox_to_anchor=(1.02, 1), loc='upper left')
plt.title('Product importance grouped by customer rating')
plt.xlabel('Customer Rating')
plt.ylabel('Count')
plt.xticks(rotation=0)

plt.show()

# %% [markdown]
# From the below graph we can observe,
# - In a majority products with medium importance are more and the rating is 1
# - Products with highest importance has maximum rating as 3
# - Products with lowest importance has maximum rating as 1

# %%
#Calculate Skewness (Skewness is the spreadness of the Distribution)
data_skew = data.skew()

#Display Skewness
data_skew
# Out:
# Warehouse_block       -0.279666
# Mode_of_Shipment      -0.000299
# Customer_care_calls    0.391926
# Customer_rating        0.004360
# Cost_of_the_Product   -0.157117
# Prior_purchases        1.681897
# Product_importance     0.585372
# Discount_offered       1.798929
# Weight_in_gms         -0.249747
# Reached.on.Time_Y.N   -0.394257
# dtype: float64

# %% [markdown]
# Measurement for Skewness are as follows:
#
# - If Skewness = 0, data is perfectly symmetrical / Normally Distributed
# - If Skewness is less than -1 or greater +1, distribution is highly skewed
# - If Skewness is between -1 and -0.5 or between 0.5 and 1, distribution is moderately skewed
# - If Skewness is between -0.5 and 0.5 then it is approximately symmetric
# - In a positive skew, the tail of a distribution curve is longer on the right side. This means the outliers of the distribution curve are further out towards the right and closer to the mean on the left.

# %%
#Let's run a for loop for identifying the skewness based on the above measurements

for i in data_skew:
    if i<-1:
        print("Highly negative Skewed: ",i)
    if i>1:
        print("Highly positive Skewed: ",i)
    if i>=-1 and i<=-0.5:
        print("Moderately negative Skewed: ",i)
    if i>=0.5 and i<=1:
        print("Moderately positive Skewed: ",i)
    if i>=-0.5 and i<=0.5:
        print("Approximately symmetric: ",i)
# Out:
# Approximately symmetric:  -0.27966557152853516
# Approximately symmetric:  -0.0002990710293807837
# Approximately symmetric:  0.3919257752012462
# Approximately symmetric:  0.0043595990691731885
# Approximately symmetric:  -0.15711711926913643
# Highly positive Skewed:  1.6818973153494547
# Moderately positive Skewed:  0.5853722640730209
# Highly positive Skewed:  1.7989291087435189
# Approximately symmetric:  -0.2497467569788316
# Approximately symmetric:  -0.3942573084253653

# %% [markdown]
# Skewness tells us the direction of outliers. For our dataset the Skewness for each entity are as follows:
#
# - Product_importance is Moderately positive Skewed
# - Prior_purchases and Discount_offered are Highly positive Skewed (check for outliers)
# - Rest all the entities has Approximately symmetric distribution

# %%
#Calculate Kurtosis (Kurtosis is a measure of the tailedness of a distribution)

#importing the kurtosis package from scipy.stats
from scipy.stats import kurtosis

#Fill the data
data_kurtosis = kurtosis(data)

#Display Kurtosis
data_kurtosis

#We can see that the Age coulmns kurtosis is turned to be nan so we will treat the missing values
# Out:
# array([-1.36486169,  0.10969585, -0.30939996, -1.29561052, -0.97226387,
#         4.00397584, -0.62708346,  1.99913078, -1.44755807, -1.84460357])

# %% [markdown]
# The threshold for interpreting the kurtosis value depends on the context and the distribution of the data. Below are the general guidelines for interpreting the kurtosis value:
#
# - Kurtosis < 0:
#     - It indicates a platykurtic distribution, meaning the distribution has thinner tails and is flatter compared to a normal distribution.
#     - It suggests the data has fewer outliers than a normal distribution.
#
# - Kurtosis = 0:
#     - It indicates a mesokurtic distribution, which is similar to a normal distribution.
#     - The tails of the distribution have a similar thickness to a normal distribution.
#
# - Kurtosis > 0:
#     - It indicates a leptokurtic distribution, meaning the distribution has heavier tails and is more peaked compared to a normal distribution.
#     - It suggests the data has more outliers and is more prone to extreme values.

# %%
#Let's run a for loop for identifying the type of Kurtosis based on the above measurements

for i in data_kurtosis:
    if i<0:
        print("Platykurtic: ",i)
    if i==0:
        print("Mesokurtic: ",i)
    if i>0:
        print("Leptokurtic: ",i)
# Out:
# Platykurtic:  -1.36486169336351
# Leptokurtic:  0.1096958535746646
# Platykurtic:  -0.3093999629246196
# Platykurtic:  -1.2956105223091454
# Platykurtic:  -0.9722638687045517
# Leptokurtic:  4.003975842848255
# Platykurtic:  -0.6270834645621219
# Leptokurtic:  1.9991307761240318
# Platykurtic:  -1.4475580704454785
# Platykurtic:  -1.8446035697293088

# %% [markdown]
# For our dataset the Distributions is,
# - Platykurtic distribution
#     - which indicates low kurtosis(<0) which means the distribution has thinner tails and is flatter compared to a normal distribution.
#     - It suggests the data has fewer outliers than a normal distribution.
# - Leptokurtic distribution
#     - for "Mode_of_Shipment, Prior_purchases and Discount_offered" where it is high kurtisis(>0) which means the distribution has heavier tails and is more peaked compared to a normal distribution.
#     - It suggests the data has more outliers and is more prone to extreme values.

# %%
#Outlier Detection: Checking for any outlier via boxplot (Outlier shown with a dot, small circle or star)

fig, ax = plt.subplots(figsize=(15,15)) #Sample figsize in inches,change the number accordingly
sns.boxplot(data = data,orient = 'h',ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# Inference :
# - For Cost_of_the_Product and Weight_in_gms the boxplot is clearly visible
# - For rest of the columns boxplot is too confusing, lets choose variable one at a time

# %%
#Boxplot for Warehouse_block column

sns.boxplot(data['Warehouse_block'])

#From the below graph we can figure out that there are no outliers for Warehouse_block column
# Out:
# <Axes: >

# %%
#Boxplot for Mode_of_Shipment column

sns.boxplot(data['Mode_of_Shipment'])

#From the below graph we can figure out that there are no outliers with extreme values as(1,2,3) for Mode_of_Shipment column
# Out:
# <Axes: >

# %%
#Boxplot for Customer_care_calls column

sns.boxplot(data['Customer_care_calls'])

#From the below graph we can figure out that there are no outliers for Customer_care_calls column
# Out:
# <Axes: >

# %%
#Boxplot for Customer_rating column

sns.boxplot(data['Customer_rating'])

#From the below graph we can figure out that there are no outliers for Customer_rating column
# Out:
# <Axes: >

# %%
#Boxplot for Prior_purchases column

sns.boxplot(data['Prior_purchases'])

#From the below graph we can figure out that there are outliers for Prior_purchases column
# Out:
# <Axes: >

# %%
# Detecting outlier from 'Prior_purchases' column
print("Prior_purchases Column :")
print("SUMMARY : ")
print(data['Prior_purchases'].describe().round(2))

def boxplot(datacolumn):
  sorted(datacolumn)
  Q1,Q3 = np.percentile(datacolumn , [25,75])
  IQR = (Q3 - Q1)
  lower_range = Q1 - (1.5 * IQR)
  upper_range = Q3 + (1.5 * IQR)
  return Q1,Q3,IQR,lower_range,upper_range

Q1,Q3,IQR,lower_range,upper_range = boxplot(data.Prior_purchases)
print("BOX PLOT VALUES : ")
print("First Quartile :",Q1.round(2))
print("Second Quartile :",Q3.round(2))
print("IQR Range :",IQR.round(2))
print("Lower Range :",lower_range.round(2))
print("Upper Range :",upper_range.round(2))

# Inference : 
# For Prior_purchases Column in the Dataset
# Lower Range : 1.5 so anything less than 1.5 will be treated as Outlier
# Minimum Value : 2.00 which is greater than 1.5 so not an outlier
# 25% Percentile / 1st Quartile / Lower Quartile / Q1 : 3.00
# 50% Percentile / Median / 2nd Quantile / Q2 : 3.00
# 75% Percentile / 3rd Quartile / Higher Quartile / Q3 : 4.00
# IQR Range / Q3 - Q1 : 1.0
# Upper Range : 5.5 so anything more than 5.5 will be treated as Outlier
# Maximum Value : 5.50 which is greater than 5.5 so IT IS AN OUTLIER
# Out:
# Prior_purchases Column :
# SUMMARY :
# count    10999.00
# mean         3.57
# std          1.52
# min          2.00
# 25%          3.00
# 50%          3.00
# 75%          4.00
# max         10.00
# Name: Prior_purchases, dtype: float64
# BOX PLOT VALUES :
# First Quartile : 3.0
# Second Quartile : 4.0
# IQR Range : 1.0
# Lower Range : 1.5
# Upper Range : 5.5

# %%
# Upper and Lower Range of the dataset

upper_outlier = len(data[data.Prior_purchases > upper_range])
lower_outlier = len(data[data.Prior_purchases < lower_range])
total = len(data[(data.Prior_purchases < lower_range) | (data.Prior_purchases > upper_range)])

print("Total Range is as folows")
print("Lower Range :",lower_range.round(2))
print("Upper Range :", upper_range.round(2))
print("So Number should not be less than 'Lower Range' or more than 'Upper Range' else OUTLIERS")
print("Total Outlier ABOVE UPPER RANGE :",upper_outlier)
print("Total Outlier BELOW LOWER RANGE :",lower_outlier)
print("Total Outlier in 'Prior_purchases' Column in the Dataset :", total)
# Out:
# Total Range is as folows
# Lower Range : 1.5
# Upper Range : 5.5
# So Number should not be less than 'Lower Range' or more than 'Upper Range' else OUTLIERS
# Total Outlier ABOVE UPPER RANGE : 1003
# Total Outlier BELOW LOWER RANGE : 0
# Total Outlier in 'Prior_purchases' Column in the Dataset : 1003

# %%
# Outlier Treatment 

# Replacing Value below lower range with lower range value
# AND Replacing Value above higher range with higher range value

print("Lower Range :",lower_range.round(1))
print("Upper Range :",upper_range.round(1))
data['Prior_purchases'] = np.where(data['Prior_purchases'] < 1.5, 1.5, data['Prior_purchases'])
data['Prior_purchases'] = np.where(data['Prior_purchases'] > 5.5, 5.5, data['Prior_purchases'])

print("After Outlier Treatment")
sns.boxplot(data['Prior_purchases'])
# Out:
# Lower Range : 1.5
# Upper Range : 5.5
# After Outlier Treatment
# <Axes: >

# %%
#Boxplot for Product_importance column

sns.boxplot(data['Product_importance'])

#From the below graph we can figure out that there are no outliers for Product_importance column
# Out:
# <Axes: >

# %%
#Boxplot for Discount_offered column

sns.boxplot(data['Discount_offered'])

#From the below graph we can figure out that there are outliers for Discount_offered column
# Out:
# <Axes: >

# %%
# Detecting outlier from 'Discount_offered' column
print("Discount_offered Column :")
print("SUMMARY : ")
print(data['Discount_offered'].describe().round(2))

def boxplot(datacolumn):
  sorted(datacolumn)
  Q1,Q3 = np.percentile(datacolumn , [25,75])
  IQR = (Q3 - Q1)
  lower_range = Q1 - (1.5 * IQR)
  upper_range = Q3 + (1.5 * IQR)
  return Q1,Q3,IQR,lower_range,upper_range

Q1,Q3,IQR,lower_range,upper_range = boxplot(data.Discount_offered)
print("BOX PLOT VALUES : ")
print("First Quartile :",Q1.round(2))
print("Second Quartile :",Q3.round(2))
print("IQR Range :",IQR.round(2))
print("Lower Range :",lower_range.round(2))
print("Upper Range :",upper_range.round(2))

# Inference : 
# For Discount_offered Column in the Dataset
# Lower Range : -5.0 so anything less than -5.0 will be treated as Outlier
# Minimum Value : 1.00 which is greater than -5.0 so not an outlier
# 25% Percentile / 1st Quartile / Lower Quartile / Q1 : 4.00
# 50% Percentile / Median / 2nd Quantile / Q2 : 7.00
# 75% Percentile / 3rd Quartile / Higher Quartile / Q3 : 10.00
# IQR Range / Q3 - Q1 : 6.0
# Upper Range : 19.0 so anything more than 19.0 will be treated as Outlier
# Maximum Value : 65.00 which is greater than 19.0 so IT IS AN OUTLIER
# Out:
# Discount_offered Column :
# SUMMARY :
# count    10999.00
# mean        13.37
# std         16.21
# min          1.00
# 25%          4.00
# 50%          7.00
# 75%         10.00
# max         65.00
# Name: Discount_offered, dtype: float64
# BOX PLOT VALUES :
# First Quartile : 4.0
# Second Quartile : 10.0
# IQR Range : 6.0
# Lower Range : -5.0
# Upper Range : 19.0

# %%
# Upper and Lower Range of the dataset

upper_outlier = len(data[data.Discount_offered > upper_range])
lower_outlier = len(data[data.Discount_offered < lower_range])
total = len(data[(data.Discount_offered < lower_range) | (data.Discount_offered > upper_range)])

print("Total Range is as folows")
print("Lower Range :",lower_range.round(2))
print("Upper Range :", upper_range.round(2))
print("So Number should not be less than 'Lower Range' or more than 'Upper Range' else OUTLIERS")
print("Total Outlier ABOVE UPPER RANGE :",upper_outlier)
print("Total Outlier BELOW LOWER RANGE :",lower_outlier)
print("Total Outlier in 'Discount_offered' Column in the Dataset :", total)
# Out:
# Total Range is as folows
# Lower Range : -5.0
# Upper Range : 19.0
# So Number should not be less than 'Lower Range' or more than 'Upper Range' else OUTLIERS
# Total Outlier ABOVE UPPER RANGE : 2209
# Total Outlier BELOW LOWER RANGE : 0
# Total Outlier in 'Discount_offered' Column in the Dataset : 2209

# %%
# Outlier Treatment 

# Replacing Value below lower range with lower range value
# AND Replacing Value above higher range with higher range value

print("Lower Range :",lower_range.round(1))
print("Upper Range :",upper_range.round(1))
data['Discount_offered'] = np.where(data['Discount_offered'] < -5.0, -5.0, data['Discount_offered'])
data['Discount_offered'] = np.where(data['Discount_offered'] > 19.0, 19.0, data['Discount_offered'])

print("After Outlier Treatment")
sns.boxplot(data['Discount_offered'])
# Out:
# Lower Range : -5.0
# Upper Range : 19.0
# After Outlier Treatment
# <Axes: >

# %%
#Boxplot for Reached.on.Time_Y.N column

sns.boxplot(data['Reached.on.Time_Y.N'])

#From the below graph we can figure out that there are no outliers for Reached.on.Time_Y.N column as the values are (1,2)
# Out:
# <Axes: >

# %%
#Let's check again for the data type, this time we will use data.info()

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Warehouse_block      10999 non-null  int64
#  1   Mode_of_Shipment     10999 non-null  int64
#  2   Customer_care_calls  10999 non-null  int64
#  3   Customer_rating      10999 non-null  int64
#  4   Cost_of_the_Product  10999 non-null  int64
#  5   Prior_purchases      10999 non-null  float64
#  6   Product_importance   10999 non-null  int64
#  7   Discount_offered     10999 non-null  float64
#  8   Weight_in_gms        10999 non-null  int64
#  9   Reached.on.Time_Y.N  10999 non-null  int64
# dtypes: float64(2), int64(8)
# memory usage: 859.4 KB

# %%
#Let's check again Skewness and kurtosis after the outlier being treated

data.skew()
# Out:
# Warehouse_block       -0.279666
# Mode_of_Shipment      -0.000299
# Customer_care_calls    0.391926
# Customer_rating        0.004360
# Cost_of_the_Product   -0.157117
# Prior_purchases        0.415785
# Product_importance     0.585372
# Discount_offered       0.712340
# Weight_in_gms         -0.249747
# Reached.on.Time_Y.N   -0.394257
# dtype: float64

# %%
data.kurtosis()
# Out:
# Warehouse_block       -1.364937
# Mode_of_Shipment       0.110291
# Customer_care_calls   -0.308995
# Customer_rating       -1.295654
# Cost_of_the_Product   -0.972160
# Prior_purchases       -0.948741
# Product_importance    -0.626823
# Discount_offered      -0.817002
# Weight_in_gms         -1.447671
# Reached.on.Time_Y.N   -1.844897
# dtype: float64

# %% [markdown]
# - We have treated the outlier
# - The overall skewness gives Approximately symmetric distribution
# - The overall kurtosis gives Platykurtic distribution
# - There are no missing or duplicate values
# - We have applied feature engineering to our dataset.
#
# Now we can consider our data to be ready for processing

# %% [markdown]
# # Step 2. Divide data into Input and Output.
#
# Create X as Input(Independent variables) and y as Output(Dependent variable).

# %%
#For our data y is 'Reached.on.Time_Y.N' column i.e, Dependent variable and X is rest of the columns i.e, independent variables 

X = data.drop('Reached.on.Time_Y.N', axis=1).values     #Input
y = data['Reached.on.Time_Y.N'].values                  #Output

# %%
#Let's check the correlation for the output variable

correlation_matrix = data.corr()
correlation_matrix['Reached.on.Time_Y.N']
# Out:
# Warehouse_block        0.005214
# Mode_of_Shipment      -0.007797
# Customer_care_calls   -0.067126
# Customer_rating        0.013119
# Cost_of_the_Product   -0.073587
# Prior_purchases       -0.074934
# Product_importance     0.020517
# Discount_offered       0.410716
# Weight_in_gms         -0.268793
# Reached.on.Time_Y.N    1.000000
# Name: Reached.on.Time_Y.N, dtype: float64

# %%
# plot the heat map to visually identify the correlation of the dataset against the output variable

plt.figure(figsize=(15,15),dpi=150)
sns.heatmap(data.drop('Reached.on.Time_Y.N', axis=1).corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# As we see above, there is a high correlation b/w
#
# - Weight_in_gms & Discount_offered
# - Weight_in_gms & Customer_care_calls
# - Weight_in_gms & Prior_purchases

# %%
#let's visualize the Customer care calls, product importance and customer ratings against product reached on time

plt.figure()
sns.pairplot(data, vars=['Customer_care_calls', 'Product_importance', 'Customer_rating'], hue = "Reached.on.Time_Y.N", markers=["o", "s"])
plt.show()

# %%
# importing counter class from collections module to check the number of 1 and 0 in the output variable

from collections import Counter
counter = Counter(y)
print(counter)
# Out:
# Counter({1: 6563, 0: 4436})

# %%
#Using Bar graph let's visualize the counts of output

f, ax = plt.subplots(figsize=(7, 5))
sns.countplot(x=y, data=data) #X means input and y is my desired output
plt.title('# Reached vs Unreached')
plt.xlabel('Electronic Item (0==Reached)')
# Out:
# Text(0.5, 0, 'Electronic Item (0==Reached)')

# %% [markdown]
# As our Output(Dependent variable) has values 1 and 0, we can classify the output under Binary Classification.

# %% [markdown]
# # Step 3. Split data into two parts train and test.
#
# For any model to work,
# - We need to first train the model and then perform the testing
# - So we need to divide our data in 2 parts : Training data and Testing data
# - Training(80%) + Testing(20%) (the distribution can also be 50-50%, 70-30%, 60-40%)
#
# - So our X and y will have XTraining, XTesting and yTraining, yTesting

# %%
# Splitting dataset into training and test data

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=0000)

# %% [markdown]
# - train_test_split will take random set ie, 80-20% data will be randomly choosen.
# - So if we run the code 1000 times, for every time the data and result will be different.
# - Hence we write random_state=0000 which will make sure the data is same every time. The chosen data will be around 0000
# - random_state is the seed value used by the random number generator, it can be any integer.
# - train_size=0.8 means 80% data to Training

# %%
data.head() #check the data whether it is standard
# Out:
#    Warehouse_block  Mode_of_Shipment  Customer_care_calls  Customer_rating
# 0                4                 1                    4                2  \
# 1                5                 1                    4                5
# 2                1                 1                    2                2
# 3                2                 1                    3                3
# 4                3                 1                    2                2
#
#    Cost_of_the_Product  Prior_purchases  Product_importance  Discount_offered
# 0                  177              3.0                   1              19.0  \
# 1                  216              2.0                   1              19.0
# 2                  183              4.0                   1              19.0
# 3                  176              4.0                   2              10.0
# 4                  184              3.0                   2              19.0
#
#    Weight_in_gms  Reached.on.Time_Y.N
# ...

# %% [markdown]
# # Step 4. Implement different machine learning models
#
# - As our output variable is Binary in nature i.e; only 2 valid results are present, we will be using Binary classification.
# - In machine learning, binary classification is a supervised learning algorithm that categorizes new observations into one of two classes.
# - There are several machine learning techniques we can consider. The choice of technique often depends on factors such as the size and quality of your dataset, the complexity of the problem, and your computational resources.
# - Here are a few common techniques which we will use to identify the best fit model for the dataset and then we will compare their results.
#
#     - Naive Bayes Model (Bernoulli Naive Bayes)
#     - Logistic Regression
#     - K-Nearest Neighbors (KNN)
#     - Support Vector Machines (SVM)
#     - Decision Tree
#     - Bagging Decision Tree
#     - Boosted Decision Tree
#     - Random Forest Algorithm

# %% [markdown]
# # Naive Bayes Model (Bernoulli Naive Bayes)
#
# - Naive Bayes is a supervised machine learning algorithm to predict the probability of different classes based on numerous attributes.
# - It indicates the likelihood of occurrence of an event.
# - Naive Bayes is also known as conditional probability.
#
# - There are four types of the Naive Bayes Model, which are explained below:
#     - Gaussian Naive Bayes
#         - It is a straightforward algorithm used when the attributes are continuous.
#         - The attributes present in the data should follow the rule of Gaussian distribution or normal distribution.
#         - Under lenient conditions, the error will be two times greater than Optimal Naive Bayes.
#
#     - Optimal Naive Bayes
#         - Optimal Naive Bayes selects the class that has the greatest posterior probability of happenings.
#         - As per the name, it is optimal. But it will go through all the possibilities, which is very slow and time-consuming.
#
#     - Bernoulli Naive Bayes
#         - Bernoulli Naive Bayes is an algorithm that is useful for data that has binary or boolean attributes.
#         - The attributes will have a value of yes or no, useful or not, granted or rejected, etc.
#
#     - Multinominal Naive Bayes
#         - Multinominal Naive Bayes is used on documentation classification issues.
#         - The features needed for this type are the frequency of the words converted from the document.

# %% [markdown]
# As our output dataset has binary attributes, use the Bernoulli Naive Bayes modelling method

# %%
#importing BernoulliNB method from sklearn's naive_bayes class

from sklearn.naive_bayes import BernoulliNB 
bnb = BernoulliNB(binarize=0.0)   #passed the parameter

# %%
#fitting the trained data to the model

model = bnb.fit(X_train, y_train)
model
# Out:
# BernoulliNB()

# %%
#Importing all the metrics packages

from sklearn.metrics import roc_curve, roc_auc_score, classification_report, accuracy_score, confusion_matrix

# %%
#Prediction for the trained data and displaying the score

y_pred_train= bnb.predict(X_train)
#print(bnb.score(X_train, y_train)*100)  #Can also use the exact code for printing the score

# Model Accuracy, how often is the classifier correct for the train data
print('Training accuracy score for Bernoulli Naive Bayes model: {0:0.4f}'.format(accuracy_score(y_train, y_pred_train)*100))
# Out:
# Training accuracy score for Bernoulli Naive Bayes model: 59.9045

# %%
# comparing actual response values (y_test) with predicted response values (y_pred_test)

y_pred_test= bnb.predict(X_test)

# Model Accuracy, how often is the classifier correct for test data
print('Testing accuracy score for Bernoulli Naive Bayes model: {0:0.4f}'.format(accuracy_score(y_test, y_pred_test)*100))
# Out:
# Testing accuracy score for Bernoulli Naive Bayes model: 58.7273

# %% [markdown]
# Let's calculate ROC Curve  and AUC
#
# The Receiver Operating Characteristic Area Under the Curve (ROC-AUC) score is a metric used to evaluate the performance of a classification model
#
# - ROC curves and AUC can provide a more comprehensive view of model performance across different thresholds.
# - They help to assess the trade-off between true positive rate (recall) and false positive rate (1 - specificity) at various threshold levels.
# - Higher ROC-AUC values indicate better discrimination performance, while a value of 0.5 suggests no discrimination (similar to random guessing).
# - It's a useful metric for comparing and evaluating the overall performance of different classifiers, especially when dealing with imbalanced datasets or when you want to assess the classifier's ability to rank instances by their likelihood of belonging to the positive class.

# %%
# Making the ROC AUC Score

roc_auc_score(y_test, y_pred_test)
# Out:
# 0.5

# %% [markdown]
# Let's calculate RMSE
#
# - Root Mean Square Error (RMSE) is a commonly used metric to evaluate the performance of a model particularly in the context of predicting continuous numerical values.
# - RMSE measures the average magnitude of the errors or residuals between the predicted values and the actual observed values in a dataset.
# - It quantifies how well the model's predictions match the true values, with lower RMSE values indicating better predictive accuracy.
# - We are considering the RMSE value even though are output variable is categorical.

# %%
#Calculating the RMSE value. It helps us to identify the prediction performance for the test dataset
#(rmse value should be near to 0)

from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred_test)

from math import sqrt
rmse = sqrt(mse)
print("RMSE value :",rmse)
# Out:
# RMSE value : 0.6424385361474456

# %% [markdown]
# Let's calculate Cross-Validation
#
# - Cross-validation is a widely used technique for assessing and validating the performance of a predictive model.
# - It helps evaluate a model's ability to generalize to unseen data and provides a more robust estimate of its performance compared to traditional train-test splitting.
# - The main idea behind cross-validation is to partition the dataset into multiple subsets, train and test the model multiple times, and then aggregate the performance metrics to get a more reliable estimate.

# %%
#Let's calculate the CrossValidation score for the model for 10 folds

from sklearn.model_selection import cross_val_score

scores = cross_val_score(bnb, X, y, scoring='accuracy', cv = 10)

print("Cross Validation Scores: ", scores)
print("Average Cross Validation Score: ", scores.mean()*100)
print("Number of Cross Validation Scores used in Average: ", len(scores))
# Out:
# Cross Validation Scores:  [0.59727273 0.59727273 0.59727273 0.59636364 0.59636364 0.59636364
#  0.59636364 0.59636364 0.59636364 0.59690628]
# Average Cross Validation Score:  59.6690627843494
# Number of Cross Validation Scores used in Average:  10

# %% [markdown]
# Let's implement Confusion Matrix:
#
# Confusion Matrix: It is the table presentation for TP, FP, FN, TN where TP+Tn gives the count of correct predictions and FP+FN gives the count of incorrect predictions
#    - True Positives (TP): Instances correctly classified as class 1 (positive class).
#    - True Negatives (TN): Instances correctly classified as class 0 (negative class).
#    - False Positives (FP): Instances incorrectly classified as class 1 when they are actually class 0 (Type I error).
#    - False Negatives (FN): Instances incorrectly classified as class 0 when they are actually class 1 (Type II error).

# %%
# Making the Confusion Matrix = The table in the PPT with TP, FP, FN, TN

print('Confusion Matrix : \n', confusion_matrix(y_test, y_pred_test))
sns.heatmap(confusion_matrix(y_test, y_pred_test),fmt='.4g',annot=True)
# Out:
# Confusion Matrix :
#  [[   0  908]
#  [   0 1292]]
# <Axes: >

# %% [markdown]
# Let's generate classification report
#
# Classification Report: It provides the metrics that are typically calculated separately for each class(output fields) in the classification problem.
#    - The classes are represented as "class 0" and "class 1" or numerically as "0" and "1."
#         - Class 0: Often referred to as the "negative class" or "majority class." This class represents the instances in our dataset that belong to the class we are not trying to predict. It's the class we're trying to distinguish from the positive class (class 1).
#         - Class 1: Often referred to as the "positive class" or "minority class." This class represents the instances in our dataset that belong to the class we are trying to predict or detect. It's the class we're interested in identifying or classifying.
#    - Precision, recall, and F1-score are three important metrics used to evaluate the performance of classification models, particularly in cases where class imbalance exists.
#         - Precision: it tells us how many of the predicted positive instances are actually positive. It is concerned with minimizing false positives.
#              - It answers the question: "Of all the instances the model predicted as positive, how many were actually positive?"
#              - Precision is calculated as: TP / (TP + FP)
#              - A high precision indicates that when the model predicts a positive class, it is likely to be correct, but it doesn't consider whether the model is missing any actual positive instances.
#         - Recall: it tells you how many of the actual positive instances were correctly predicted. It is concerned with minimizing false negatives.
#              - It answers the question: "Of all the actual positive instances, how many did the model correctly predict as positive?"
#              - Recall is calculated as: TP / (TP + FN)
#              - A high recall indicates that the model is effective at identifying most of the actual positive instances, but it doesn't consider whether there are many false alarms (false positives).
#         - F1-Score: it is a balanced measure that considers both precision and recall. It is useful when we want to evaluate the overall performance of a classification model, especially in imbalanced datasets.
#              - F1-Score is calculated as: 2 * (Precision * Recall) / (Precision + Recall)

# %%
#Classification report of test data

print('classification report : \n', classification_report(y_test, y_pred_test))
# Out:
# classification report :
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       908
#            1       0.59      1.00      0.74      1292
#
#     accuracy                           0.59      2200
#    macro avg       0.29      0.50      0.37      2200
# weighted avg       0.34      0.59      0.43      2200

# %% [markdown]
# Inference:
#
# - Accuracy of Training was 59.9045% and in testing the accuracy is 58.7273% which means our model is Good Fit Model!
# - By observing the confusion matrix we can conclude there are 1292 correct prediction and 908 incorrect predictions
# - From the classification report for class 0, precision recall and f1-score is 0 and for class 1 the precision is 0.59, recall is 1 and f1-score is 0.74
# - The area under the ROC curve score came to be 0.5, which indicates the corresponding classification model is basically worthless, as its predictive ability is no better than random guessing.
# - The RMSE value came to be 0.6424, which indicates more prone to error
# - Average Cross Validation Score of the model is the average of the accuracy of each fold which came to be 59.669, which indicates Moderate Performance and Room for Improvement
# - In the confusion matrix the True positive and False negative came to be 0, which means
#      - Our model did not correctly identify any positive cases (TP = 0).
#      - Additionally, your model did not incorrectly classify any positive cases as negative (FN = 0).
#      - This could indicate that your model is not sensitive enough to the positive class
#      - And it might be failing to recognize positive instances.
#
# Let's try few more Machine Learning models

# %% [markdown]
# # Logistic Regression:
#
# Logistic Regression is a simple and widely used technique for binary/binomial classification. It models the probability of the binary outcome using a logistic function and makes predictions based on a threshold.
#
# Logistic Function (Sigmoid Function):
#
# - The sigmoid function is a mathematical function used to map the predicted values to probabilities.
# - It maps any real value into another value within a range of 0 and 1. o The value of the logistic regression must be between 0 and 1, which cannot go beyond this limit, so it forms a curve like the “S” form.
# - The S-form curve is called the Sigmoid function or the logistic function.
# - In logistic regression, we use the concept of the threshold value, which defines the probability of either 0 or 1. Such as values above the threshold value tends to 1, and a value below the threshold values tends to 0.

# %%
#importing LogisticRegression method from sklearn.linear_model

from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
#fitting the trained data to the model

lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#Prediction for the trained data
y_train_hat = lr.predict(X_train)

# Model Accuracy, how often is the classifier correct for the train data
print('Training accuracy score for Logistic Regression model: {0:0.4f}'.format(accuracy_score(y_train, y_train_hat)*100))

#this means 63.598% our model will give the corret result
# Out:
# Training accuracy score for Logistic Regression model: 63.5981

# %%
#Checking probablities for the train data (Performance = probablities)

y_train_hat_probs = lr.predict_proba(X_train)[:,1]
y_train_hat_probs
# Out:
# array([0.91637779, 0.59369391, 0.59691697, ..., 0.36711826, 0.43378732,
#        0.8803642 ])

# %%
#Model Prediction for test data
test_preds = lr.predict(X_test)

# Model Accuracy, how often is the classifier correct for test data
print('Testing accuracy score for Logistic Regression model: {0:0.4f}'.format(accuracy_score(y_test, test_preds)*100))

#this means 63.045% our model will give the corret result
# Out:
# Testing accuracy score for Logistic Regression model: 63.0455

# %%
# Making the ROC AUC Score

roc_auc_score(y_test, test_preds)
# Out:
# 0.6192513059014471

# %%
#Let's calculate the rmse value

mse = mean_squared_error(y_test, test_preds)
rmse = sqrt(mse)
print("RMSE value :",rmse)
# Out:
# RMSE value : 0.6079025041447473

# %%
#Let's calculate the CrossValidation score for the model for 10 folds

scores = cross_val_score(lr, X, y, scoring='accuracy', cv = 10)

print("Cross Validation Scores: ", scores)
print("Average Cross Validation Score: ", scores.mean()*100)
print("Number of Cross Validation Scores used in Average: ", len(scores))
# Out:
# Cross Validation Scores:  [0.78818182 0.78272727 0.76454545 0.77454545 0.69090909 0.42545455
#  0.48181818 0.47       0.49090909 0.48771611]
# Average Cross Validation Score:  61.5680701464141
# Number of Cross Validation Scores used in Average:  10

# %%
#Confusion Matrix = The table in the PPT with TP, FP, FN, TN

print('Confusion Matrix : \n', confusion_matrix(y_test, test_preds))
sns.heatmap(confusion_matrix(y_test, test_preds),fmt='.4g',annot=True)
# Out:
# Confusion Matrix :
#  [[504 404]
#  [409 883]]
# <Axes: >

# %%
#Classification report of test data

print('classification report : \n', classification_report(y_test, test_preds))
# Out:
# classification report :
#                precision    recall  f1-score   support
#
#            0       0.55      0.56      0.55       908
#            1       0.69      0.68      0.68      1292
#
#     accuracy                           0.63      2200
#    macro avg       0.62      0.62      0.62      2200
# weighted avg       0.63      0.63      0.63      2200

# %% [markdown]
# Inference:
#
# - Accuracy of Training was 63.5981% and in testing the accuracy is 63.0455% which means our model is exact Good Fit Model!
# - By observing the confusion matrix we can conclude there are 504 + 883 = 1387 correct prediction and 404 + 409 = 813 incorrect predictions which is better than Bernoulli Naive Bayes Model (908 incorrect predictions)
# - The area under the ROC curve score came to be 0.6192, which indicates Discrimination Ability, Moderate Performance and Room for Improvement
# - The RMSE value came to be 0.607, which indicates more prone to error
# - Average Cross Validation Score of the model came to be 61.568, which indicates Moderate Performance and Room for Improvement
# - Let's standardise our model and then check the result

# %% [markdown]
# Lets use StandardScaler from preprocessing class
#
# - StandardScaler removes the mean and scales each feature/variable to unit variance.
# - This operation is performed feature-wise in an independent way.
# - StandardScaler can be influenced by outliers (if they exist in the dataset) since it involves the estimation of the empirical mean and standard deviation of each feature. We have already removed the outliers from the dataset.

# %%
#importing StandardScaler subclass from the class preprocessing

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

#importing Pipeline - its purpose is to assemble several steps that can be cross-validated together while setting different parameters.

from sklearn.pipeline import Pipeline
model1 = Pipeline([('standardize', scaler),    #Our new model's name is model1
                    ('log_reg', lr)])

# %%
#Let's fit the train data to the newly build model (model1)

model1.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardize', StandardScaler()),
#                 ('log_reg', LogisticRegression())])

# %%
#Predicting the train data and checking the score
y_train_hat = model1.predict(X_train)

# Model Accuracy, how often is the classifier correct for the train data
print('Training accuracy score for LR model after Standardisation: {0:0.4f}'.format(accuracy_score(y_train, y_train_hat)*100))
# Out:
# Training accuracy score for LR model after Standardisation: 63.5186

# %%
#Now predicting the test data and checking the score
test_preds = model1.predict(X_test)

# Model Accuracy, how often is the classifier correct for test data
print('Testing accuracy score for LR model after Standardisation: {0:0.4f}'.format(accuracy_score(y_test, test_preds)*100))
# Out:
# Testing accuracy score for LR model after Standardisation: 63.4091

# %%
# Making the ROC AUC Score

roc_auc_score(y_test, test_preds)
# Out:
# 0.6207106422443774

# %%
#Let's calculate the rmse value

mse = mean_squared_error(y_test, test_preds)
rmse = sqrt(mse)
print("RMSE value :",rmse)
# Out:
# RMSE value : 0.6049041997780235

# %%
#Let's calculate the CrossValidation score for the model for 10 folds

scores = cross_val_score(model1, X, y, scoring='accuracy', cv = 10)

print("Cross Validation Scores: ", scores)
print("Average Cross Validation Score: ", scores.mean()*100)
print("Number of Cross Validation Scores used in Average: ", len(scores))
# Out:
# Cross Validation Scores:  [0.79545455 0.78909091 0.78818182 0.78363636 0.71090909 0.41090909
#  0.47272727 0.46454545 0.49272727 0.47679709]
# Average Cross Validation Score:  61.849789064438745
# Number of Cross Validation Scores used in Average:  10

# %%
#Confusion Matrix = The table in the PPT with TP, FP, FN, TN

print('Confusion Matrix : \n', confusion_matrix(y_test, test_preds))
sns.heatmap(confusion_matrix(y_test, test_preds),fmt='.4g',annot=True)
# Out:
# Confusion Matrix :
#  [[494 414]
#  [391 901]]
# <Axes: >

# %%
#Classification report of test data

print('classification report : \n', classification_report(y_test, test_preds))
# Out:
# classification report :
#                precision    recall  f1-score   support
#
#            0       0.56      0.54      0.55       908
#            1       0.69      0.70      0.69      1292
#
#     accuracy                           0.63      2200
#    macro avg       0.62      0.62      0.62      2200
# weighted avg       0.63      0.63      0.63      2200

# %% [markdown]
# Inference:
#
# - Accuracy of Training was 63.5186% and in testing the accuracy is 63.4091% which means are model is exact and Good Fit Model!
# - By observing the confusion matrix we can conclude there are 494 + 901 = 1395 correct prediction and 414 + 391 = 805 incorrect predictions.
# - The area under the ROC curve score came to be 0.6207, which indicates moderate discrimination ability of the model but leaves room for improvement.
# - The RMSE value came to be 0.6049, which indicates more prone to error
# - Average Cross Validation Score of the model came to be 61.8497, which indicates Moderate Performance and Room for Improvement
# - After Standardization, we can observe the metrics has slightly improved:
#     - Accuracy from 63.0455 to 63.4091
#     - Correct predictions has been improved from 1387 to 1395
#     - Incorrect predictions has been reduced from 813 to 805
#     - For class-0 the precision has increased while the recall has decreased and for class-1, precision is same and recall has increased
#     - Area under the ROC curve score improved from 0.6192 to 0.6207
#     - RMSE value has reduced from 0.6079 to 0.6049
#     - Avg Cross Validation score improved from 61.568 to 61.8497
#
# Let's try some more algorithms to reduce the incorrect predictions

# %% [markdown]
# # K-Nearest Neighbors (KNN):
#
# - KNN classifies data points based on the majority class among their k nearest neighbors in the feature space.
# - This means when new data appears then it can be easily classified into a well suite category by using K- NN algorithm.
# - This techinque is mostly used on a smaller dataset because the computation cost is high because of calculating the distance between the data points for all the training samples.
# - K-NN algorithm can be used for Regression and for Classification but mostly it is used for the Classification problems.
# - K-NN is a non-parametric algorithm, which means it does not make any assumption on underlying data.
# - It is also called a lazy learner algorithm because it does not learn from the training set immediately instead it stores the dataset and at the time of classification, it performs an action on the dataset.
# - KNN algorithm at the training phase just stores the dataset and when it gets new data, then it classifies that data into a category that is much similar to the new data.

# %%
#importing KNN and neighbors

from sklearn.neighbors import KNeighborsClassifier

# %%
#Select the number K of the neighbors, here we're setting K as 3

model = KNeighborsClassifier(n_neighbors=3)

# %%
#Fitting K-NN classifier with the Training data

model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
#Prediction for trained data
y_pred_train = model.predict(X_train)   #X has input

# Model Accuracy, how often is the classifier correct for the train data
print('Training accuracy score for KNN at k=3: {0:0.4f}'.format(accuracy_score(y_train, y_pred_train)*100))
# Out:
# Training accuracy score for KNN at k=3: 81.9752

# %%
#Model is created, now we will predict the model with our test data
predict = model.predict(X_test)   #X has input

# Model Accuracy, how often is the classifier correct for test data
print('Testing accuracy score for KNN at k=3: {0:0.4f}'.format(accuracy_score(y_test, predict)*100))
# Out:
# Testing accuracy score for KNN at k=3: 64.3182

# %%
# Making the ROC AUC Score

roc_auc_score(y_test, predict)
# Out:
# 0.6323785136591153

# %%
#Let's calculate the rmse value

mse = mean_squared_error(y_test, predict)
rmse = sqrt(mse)
print("RMSE of K = 3 :",rmse)
# Out:
# RMSE of K = 3 : 0.5973426000363459

# %%
#Let's calculate the CrossValidation score for the model for 10 folds

scores = cross_val_score(model, X, y, scoring='accuracy', cv = 10)

print("Cross Validation Scores: ", scores)
print("Average Cross Validation Score: ", scores.mean()*100)
print("Number of Cross Validation Scores used in Average: ", len(scores))
# Out:
# Cross Validation Scores:  [0.82272727 0.81181818 0.78818182 0.81363636 0.74363636 0.47272727
#  0.45818182 0.47181818 0.47       0.47952684]
# Average Cross Validation Score:  63.3225411531144
# Number of Cross Validation Scores used in Average:  10

# %%
#Confusion matrix for the test data prediction

print('Confusion Matrix : \n', confusion_matrix(y_test, predict))   #y has output
sns.heatmap(confusion_matrix(y_test, predict),fmt='.4g',annot=True)
# Out:
# Confusion Matrix :
#  [[518 390]
#  [395 897]]
# <Axes: >

# %%
#classification report

print('classification report : \n', classification_report(y_test, predict))
# Out:
# classification report :
#                precision    recall  f1-score   support
#
#            0       0.57      0.57      0.57       908
#            1       0.70      0.69      0.70      1292
#
#     accuracy                           0.64      2200
#    macro avg       0.63      0.63      0.63      2200
# weighted avg       0.64      0.64      0.64      2200

# %% [markdown]
# Inference:
#
# - Accuracy of Training was 81.9752% and in testing the accuracy is 64.3182%, it has huge difference that means the data is overfitted
# - By observing the confusion matrix we can conclude there are 518 + 897 = 1415 correct prediction and 390 + 395 = 785 incorrect predictions which is better than Bernoulli Naive Bayes Model(908 incorrect predictions) and LR model(805 incorrect predictions)
# - The area under the ROC curve score came to be 0.6323, which indicates moderate discrimination ability of the model but leaves room for improvement
# - The RMSE value came to be 0.5973, which indicates more prone to error
# - Average Cross Validation Score of the model came to be 63.3225, which indicates moderate model performance.
# - To reduce and match the test and train accuracy we need to set more neighbors, now the Neighbors were set to 3, if we increase the value the score which change. So instead of changing the value one by one we can run a for loop or use the GridSearchCV technique

# %%
#KNN classification using GridSearchCV

knn = KNeighborsClassifier()

from sklearn.model_selection import GridSearchCV
k_range = list(range(1, 50))
param_grid = dict(n_neighbors=k_range)
  
# defining parameter range
grid = GridSearchCV(knn, param_grid, cv=10, scoring='accuracy', return_train_score=False,verbose=1)
  
# fitting the model for grid search
grid_search=grid.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 49 candidates, totalling 490 fits

# %%
#print the best K value

print(grid_search.best_params_)
# Out:
# {'n_neighbors': 48}

# %%
#Let's check the score of train data with new K value as 48

grid_search.score(X_train,y_train)
# Out:
# 0.6970110239799977

# %%
#Run the model with new k value
knn = KNeighborsClassifier(n_neighbors=48)

#Fit the model with train data
knn.fit(X_train,y_train)

#Predict the model with test data
y_train_hat = knn.predict(X_train) 

# Model Accuracy, how often is the classifier correct for the train data
print('Training accuracy score for KNN at k=48: {0:0.4f}'.format(accuracy_score(y_train, y_train_hat)*100))
# Out:
# Training accuracy score for KNN at k=48: 69.7011

# %%
#Predict the model with test data
y_test_hat = knn.predict(X_test) 

# Model Accuracy, how often is the classifier correct for test data
print('Testing accuracy score for KNN at k=48: {0:0.4f}'.format(accuracy_score(y_test, y_test_hat)*100))
# Out:
# Testing accuracy score for KNN at k=48: 66.1818

# %%
# Making the ROC AUC Score

roc_auc_score(y_test, y_test_hat)
# Out:
# 0.6809781645094857

# %%
#Let's calculate the rmse value

mse = mean_squared_error(y_test, y_test_hat)
rmse = sqrt(mse)
print("RMSE of K = 48 :",rmse)
# Out:
# RMSE of K = 48 : 0.5815340215170719

# %%
#Let's calculate the CrossValidation score for the model for 10 folds

scores = cross_val_score(knn, X, y, scoring='accuracy', cv = 10)

print("Cross Validation Scores: ", scores)
print("Average Cross Validation Score: ", scores.mean()*100)
print("Number of Cross Validation Scores used in Average: ", len(scores))
# Out:
# Cross Validation Scores:  [0.88454545 0.87909091 0.86909091 0.89       0.80090909 0.4
#  0.43454545 0.42545455 0.42272727 0.42493176]
# Average Cross Validation Score:  64.31295392505584
# Number of Cross Validation Scores used in Average:  10

# %%
#Confusion Matrix = The table in the PPT with TP, FP, FN, TN

print('Confusion Matrix : \n', confusion_matrix(y_test, y_test_hat))
sns.heatmap(confusion_matrix(y_test, y_test_hat),fmt='.4g',annot=True)
# Out:
# Confusion Matrix :
#  [[718 190]
#  [554 738]]
# <Axes: >

# %%
#Classification report

print('classification report : \n', classification_report(y_test, y_test_hat))
# Out:
# classification report :
#                precision    recall  f1-score   support
#
#            0       0.56      0.79      0.66       908
#            1       0.80      0.57      0.66      1292
#
#     accuracy                           0.66      2200
#    macro avg       0.68      0.68      0.66      2200
# weighted avg       0.70      0.66      0.66      2200

# %% [markdown]
# Inference:
#
# - Accuracy of Training was 69.7011% and in testing the accuracy is 66.1818% which means the overfitting problem is resolved and our model is somewhat a Good Fit Model!
# - By observing the confusion matrix we can conclude there are 718 + 738 = 1456 correct prediction and 554 + 190 = 744 incorrect predictions
# - The area under the ROC curve score came to be 0.6809, which indicates moderate level of discrimination ability for the model
# - The RMSE value came to be 0.5815, which indicates more prone to error
# - Average Cross Validation Score of the model came to be 64.3129, which indicates moderate model performance.
# - After changing the value of k = 48, we can observe the metrics has slightly improved:
#     - Accuracy improved from 64.3182 to 66.1818
#     - Correct predictions has been improved from 1415 to 1456
#     - Incorrect predictions has been reduced from 785 to 744, it is better than Bernoulli Naive Bayes Model(908 incorrect predictions) and LR model(805 incorrect predictions)
#     - For class-0 the precision has decreased while the recall has increased and for class-1, precision has increased and recall has decreased
#     - Area under the ROC curve score improved from 0.6323 to 0.6809
#     - RMSE value has reduced from 0.5973 to 0.5815
#     - Avg Cross Validation score improved from 63.3225 to 64.3129
#
# Let's try some more algorithms to reduce the incorrect predictions

# %% [markdown]
# # Support Vector Machines (SVM also support vector networks):
#
# - SVM is supervised learning model with associated learning algorithm that analyze data for classification and regression analysis.
# - SVMs aim to find a hyperplane that best separates the two classes in the feature space.
# - They can work well for both linearly separable and non-linearly separable data when using appropriate kernel functions.

# %%
#importing support vector classifier

from sklearn.svm import SVC
SVC = SVC()

# %%
#Using GridSearchCV let's find the best parameter for the model to give high accuracy

parameters = {"C": [0.001,0.01,0.1,0.5,1]}  #We are passing this list to check which is the best parameter
gridsearch = GridSearchCV(SVC, parameters)

#Fit training data to the model (gridsearch)
gridsearch.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=SVC(), param_grid={'C': [0.001, 0.01, 0.1, 0.5, 1]})

# %%
#Check the best parameter

gridsearch.best_params_
# Out:
# {'C': 1}

# %%
#Let's check the score of train data
from sklearn.svm import SVC

classifier = SVC(C=1.0, random_state=0)  
classifier.fit(X_train, y_train)
# Out:
# SVC(random_state=0)

# %%
#Predict the model with test data
y_train_SVC = classifier.predict(X_train) 

# Model Accuracy, how often is the classifier correct for the train data
print('Training accuracy score for SVM at c=1: {0:0.4f}'.format(accuracy_score(y_train, y_train_SVC)*100))
# Out:
# Training accuracy score for SVM at c=1: 66.2575

# %%
#Prediction for test data
y_pred = classifier.predict(X_test)  #X has input

# Model Accuracy, how often is the classifier correct for test data
print('Testing accuracy score for SVM at c=1: {0:0.4f}'.format(accuracy_score(y_test, y_pred)*100))
# Out:
# Testing accuracy score for SVM at c=1: 65.9545

# %%
# Making the ROC AUC Score

roc_auc_score(y_test, y_pred)
# Out:
# 0.6526932938721512

# %%
#Let's calculate the rmse value

mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)
print("RMSE value :",rmse)
# Out:
# RMSE value : 0.5834848288126654

# %%
#Let's calculate the CrossValidation score for the model for 10 folds

scores = cross_val_score(classifier, X, y, scoring='accuracy', cv = 10)

print("Cross Validation Scores: ", scores)
print("Average Cross Validation Score: ", scores.mean()*100)
print("Number of Cross Validation Scores used in Average: ", len(scores))
# Out:
# Cross Validation Scores:  [0.86454545 0.87454545 0.84818182 0.82363636 0.73363636 0.37545455
#  0.46727273 0.50454545 0.51727273 0.47588717]
# Average Cross Validation Score:  64.84978079245596
# Number of Cross Validation Scores used in Average:  10

# %%
#Confusion matrix

print('Confusion Matrix : \n', confusion_matrix(y_test, y_pred))
sns.heatmap(confusion_matrix(y_test, y_pred),fmt='.4g',annot=True)
# Out:
# Confusion Matrix :
#  [[557 351]
#  [398 894]]
# <Axes: >

# %%
#Classification Report

print('classification report : \n', classification_report(y_test, y_pred))
# Out:
# classification report :
#                precision    recall  f1-score   support
#
#            0       0.58      0.61      0.60       908
#            1       0.72      0.69      0.70      1292
#
#     accuracy                           0.66      2200
#    macro avg       0.65      0.65      0.65      2200
# weighted avg       0.66      0.66      0.66      2200

# %% [markdown]
# Inference:
#
# - Accuracy of Training was 66.2575% and in testing the accuracy is 65.9545%, which means are model is exact and Good Fit Model!
# - By observing the confusion matrix we can conclude there are 557 + 894 = 1451 correct prediction and 351 + 398 = 749 incorrect predictions
# - The area under the ROC curve score came to be 0.6526, which indicates moderate level of discrimination ability for your model
# - The RMSE value came to be 0.5834, which indicates more prone to error
# - Average Cross Validation Score of the model came to be 64.8497, which indicates moderate model performance.
#
# Let's standardise our model and then check the result

# %%
#Using StandardScaler method

scaler = StandardScaler()

# %%
#Fitting train data to the model(scaler)

scaler.fit(X_train)
scaled_x_train = scaler.transform(X_train)  #New X_train data
scaled_x_test = scaler.transform(X_test)    #New X_test data

# %%
#Again check the best parameter for the model to give high accuracy

SVC = SVC()

param_grid = {'C':[0.001,0.01,0.1,0.5,1]}
grid = GridSearchCV(SVC,param_grid)

#Fitting the new train data
grid.fit(scaled_x_train,y_train)
# Out:
# GridSearchCV(estimator=SVC(), param_grid={'C': [0.001, 0.01, 0.1, 0.5, 1]})

# %%
#Printing the trained data

scaled_x_train
# Out:
# array([[-2.27907802e-01,  6.02789217e-04,  1.69839981e+00, ...,
#          6.23720383e-01,  1.69401093e+00, -1.33644911e+00],
#        [-8.99495463e-01, -1.76737799e+00,  1.69839981e+00, ...,
#          6.23720383e-01, -2.68651341e-01, -1.57427641e+00],
#        [ 4.43679858e-01,  6.02789217e-04, -9.28000882e-01, ...,
#          6.23720383e-01, -1.05096152e-01,  6.99108713e-01],
#        ...,
#        [ 1.11526752e+00,  1.76858356e+00, -5.25339837e-02, ...,
#          6.23720383e-01, -9.22872097e-01,  5.83244127e-01],
#        [ 1.11526752e+00,  1.76858356e+00, -5.25339837e-02, ...,
#          6.23720383e-01, -1.08642729e+00, -1.16265223e+00],
#        [-1.57108312e+00,  1.76858356e+00, -5.25339837e-02, ...,
#         -9.35846440e-01,  1.36690055e+00,  4.96572211e-02]])

# %%
#Check the best parameter

gridsearch.best_params_
# Out:
# {'C': 1}

# %%
#Checking the score for new train data

grid.score(scaled_x_train,y_train)
# Out:
# 0.6784861916126833

# %%
#Let's check the score of train data
from sklearn.svm import SVC

SVMclassifier = SVC(C=1.0, random_state=0)  
SVMclassifier.fit(scaled_x_train,y_train)
# Out:
# SVC(random_state=0)

# %%
#Predict the model with test data
y_train_SVC = SVMclassifier.predict(scaled_x_train) 

# Model Accuracy, how often is the classifier correct for the train data
print('Training accuracy score for SVM at c=1: {0:0.4f}'.format(accuracy_score(y_train, y_train_SVC)*100))
# Out:
# Training accuracy score for SVM at c=1: 70.2125

# %%
#Prediction by using test data
y_pred = SVMclassifier.predict(scaled_x_test)

# Model Accuracy, how often is the classifier correct for test data
print('Testing accuracy score for SVM at c=1: {0:0.4f}'.format(accuracy_score(y_test, y_pred)*100))
# Out:
# Testing accuracy score for SVM at c=1: 66.6818

# %%
# Making the ROC AUC Score

roc_auc_score(y_test, y_pred)
# Out:
# 0.6944003082336575

# %%
#Let's calculate the rmse value

mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)
print("RMSE value :",rmse)
# Out:
# RMSE value : 0.5772190383050599

# %%
#Let's calculate the CrossValidation score for the model for 10 folds

scores = cross_val_score(SVMclassifier, X, y, scoring='accuracy', cv = 10)

print("Cross Validation Scores: ", scores)
print("Average Cross Validation Score: ", scores.mean()*100)
print("Number of Cross Validation Scores used in Average: ", len(scores))
# Out:
# Cross Validation Scores:  [0.86454545 0.87454545 0.84818182 0.82363636 0.73363636 0.37545455
#  0.46727273 0.50454545 0.51727273 0.47588717]
# Average Cross Validation Score:  64.84978079245596
# Number of Cross Validation Scores used in Average:  10

# %%
#Confusion Matrix

print('Confusion Matrix : \n', confusion_matrix(y_test, y_pred))
sns.heatmap(confusion_matrix(y_test, y_pred),fmt='.4g',annot=True)
# Out:
# Confusion Matrix :
#  [[774 134]
#  [599 693]]
# <Axes: >

# %%
#Classification Report

print('Classification Report : \n', classification_report(y_test,y_pred))
# Out:
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.56      0.85      0.68       908
#            1       0.84      0.54      0.65      1292
#
#     accuracy                           0.67      2200
#    macro avg       0.70      0.69      0.67      2200
# weighted avg       0.72      0.67      0.66      2200

# %% [markdown]
# Inference:
#
# - Accuracy of Training was 70.2125% and in testing the accuracy is 66.6818% which means our model is somewhat a Good Fit Model!
# - By observing the confusion matrix we can conclude there are 774 + 693 = 1467 correct prediction and 134 + 599 = 733 incorrect predictions
# - The area under the ROC curve score came to be 0.6944, which indicates moderate level of discrimination ability for your model
# - The RMSE value came to be 0.5772, which indicates moderately prone to error
# - Average Cross Validation Score of the model came to be 64.8497, which indicates moderate model performance.
# - After standardisation, we can observe the metrics has slightly improved:
#     - Accuracy improved from 65.9545 to 66.6818
#     - Correct predictions has been improved from 1451 to 1467
#     - Incorrect predictions has been reduced from 749 to 733, it is better than Bernoulli Naive Bayes Model(908 incorrect predictions), LR model(805 incorrect predictions) and KNN model(744 incorrect predictions)
#     - For class-0 the precision has decreased while the recall has increased and for class-1, precision has increased and recall has decreased
#     - Area under the ROC curve score improved from 0.6526 to 0.6944
#     - RMSE value has reduced from 0.5834 to 0.5772.
#     - The average cross validation score is the same before and after adding the parameters.
#
# Let's try some more algorithms to reduce the incorrect predictions

# %% [markdown]
# # Decision Tree
#
# - A decision tree is a flowchart-like tree structure where an internal node represents a feature(or attribute), the branch represents a decision rule, and each leaf node represents the outcome.
# - The topmost node in a decision tree is known as the root node. It learns to partition on the basis of the attribute value. It partitions the tree in a recursive manner called recursive partitioning.
# - Decision trees partition the feature space into regions and make predictions based on majority class within those regions.
# - They can handle non-linear relationships and are interpretable.

# %%
#Importing DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier

# Create Decision Tree classifer object
clf = DecisionTreeClassifier(random_state=0)

# Fit the model with the train data
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
#Predict the response for train dataset
y_pred = clf.predict(X_train)

# Model Accuracy, how often is the classifier correct for the train data
print('Training accuracy score without Criterion index: {0:0.4f}'.format(accuracy_score(y_train, y_pred)*100))

#From the below result, our model is giving 100% accuracy for the training data
# Out:
# Training accuracy score without Criterion index: 100.0000

# %%
#Predicting the response for test dataset
y_pred = clf.predict(X_test)

# Model Accuracy, how often is the classifier correct for the test data
#(Accuracy can be computed by comparing actual test set values and predicted values.)

print('Testing accuracy score without Criterion index: {0:0.4f}'.format(accuracy_score(y_test, y_pred)*100))
# Out:
# Testing accuracy score without Criterion index: 64.2273

# %%
# Making the ROC AUC Score

roc_auc_score(y_test, y_pred)
# Out:
# 0.6276765865168233

# %%
#Let's calculate the rmse value

mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)
print("RMSE value :",rmse)
# Out:
# RMSE value : 0.5981030619611245

# %%
#Let's calculate the CrossValidation score for the model for 10 folds

scores = cross_val_score(clf, X, y, scoring='accuracy', cv = 10)

print("Cross Validation Scores: ", scores)
print("Average Cross Validation Score: ", scores.mean()*100)
print("Number of Cross Validation Scores used in Average: ", len(scores))
# Out:
# Cross Validation Scores:  [0.80545455 0.80090909 0.78727273 0.80909091 0.72636364 0.48272727
#  0.50727273 0.5        0.44909091 0.4722475 ]
# Average Cross Validation Score:  63.40429315907022
# Number of Cross Validation Scores used in Average:  10

# %%
#Confusion Matrix

print('Confusion Matrix : \n', confusion_matrix(y_test, y_pred))
sns.heatmap(confusion_matrix(y_test, y_pred),fmt='.4g',annot=True)
# Out:
# Confusion Matrix :
#  [[494 414]
#  [373 919]]
# <Axes: >

# %%
#Classification Report

print('Classification Report : \n', classification_report(y_test,y_pred))
# Out:
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.57      0.54      0.56       908
#            1       0.69      0.71      0.70      1292
#
#     accuracy                           0.64      2200
#    macro avg       0.63      0.63      0.63      2200
# weighted avg       0.64      0.64      0.64      2200

# %% [markdown]
# Inference:
#
# - Accuracy of Training was 100% and in testing the accuracy is 64.1818% which is a huge difference and we can conclude that the model has under-fitting problem, we can reduce this problem by adding the parameters (criterion, max_depth, splitter)
# - By observing the confusion matrix we can conclude there are 494 + 919 = 1413 correct prediction and 414 + 373 = 787 incorrect predictions. The incorrect count is greater than the SVM model.
# - The area under the ROC curve score came to be 0.6276, which indicates moderate discrimination ability of your model but leaves room for improvement.
# - The RMSE value came to be 0.5981, which indicates more prone to error
# - Average Cross Validation Score of the model came to be 63.4042, moderate model performance.
#
# Let's improve this accuracy by tuning the parameters in the decision tree algorithm.

# %%
# Create Decision Tree classifer object with criterion="entropy". Entropy uses ID3 algorithm.

clf = DecisionTreeClassifier(criterion="entropy", max_depth=3, random_state=0)

# Fit the model with the train data
clf = clf.fit(X_train,y_train)

#Predicting the response for train dataset
y_entropy_pred = clf.predict(X_train)

# Model Accuracy, how often is the classifier correct for training data
print('Training accuracy score with Criterion entropy index: {0:0.4f}'.format(accuracy_score(y_train, y_entropy_pred)*100))
# Out:
# Training accuracy score with Criterion entropy index: 67.9623

# %%
#Predict the response for test dataset
y_entropy_pred = clf.predict(X_test)

# Model Accuracy, how often is the classifier correct for test data
print('Testing accuracy score with Criterion entropy index: {0:0.4f}'.format(accuracy_score(y_test, y_entropy_pred)*100))
# Out:
# Testing accuracy score with Criterion entropy index: 67.4091

# %%
# We can also use the GINI criterion for the Decision Tree Classifier. GINI means CART algorithm.
clf_gini = DecisionTreeClassifier(criterion='gini', max_depth=3, random_state=0)  

# Train Decision Tree Classifer
clf_gini.fit(X_train, y_train)

#Predict the response for test dataset
y_pred_gini = clf_gini.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print('Testing accuracy score with Criterion gini index: {0:0.4f}'.format(accuracy_score(y_test,y_pred_gini)*100))
# Out:
# Testing accuracy score with Criterion gini index: 67.4091

# %%
# Making the ROC AUC Score

roc_auc_score(y_test, y_entropy_pred)
# Out:
# 0.7138490337011225

# %%
#Let's calculate the rmse value

mse = mean_squared_error(y_test, y_entropy_pred)
rmse = sqrt(mse)
print("RMSE value :",rmse)
# Out:
# RMSE value : 0.570884481229864

# %%
#Let's calculate the CrossValidation score for the model for 10 folds

scores = cross_val_score(clf, X, y, scoring='accuracy', cv = 10)

print("Cross Validation Scores: ", scores)
print("Average Cross Validation Score: ", scores.mean()*100)
print("Number of Cross Validation Scores used in Average: ", len(scores))
# Out:
# Cross Validation Scores:  [0.91090909 0.92454545 0.94818182 0.87545455 0.76090909 0.35363636
#  0.41       0.41636364 0.41909091 0.40582348]
# Average Cross Validation Score:  64.2491438497808
# Number of Cross Validation Scores used in Average:  10

# %%
#Confusion Matrix

print('Confusion Matrix : \n', confusion_matrix(y_test, y_entropy_pred))
sns.heatmap(confusion_matrix(y_test, y_entropy_pred),fmt='.4g',annot=True)
# Out:
# Confusion Matrix :
#  [[855  53]
#  [664 628]]
# <Axes: >

# %%
#Classification Report

print('Classification Report : \n', classification_report(y_test,y_entropy_pred))
# Out:
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.56      0.94      0.70       908
#            1       0.92      0.49      0.64      1292
#
#     accuracy                           0.67      2200
#    macro avg       0.74      0.71      0.67      2200
# weighted avg       0.77      0.67      0.66      2200

# %%
#Let's plot the decision tree for train data. We're using the GINI Criterion model as GINI and ENTROPY gave the same results

plt.figure(figsize=(12,8))

from sklearn import tree

tree.plot_tree(clf_gini.fit(X_train,y_train))
# Out:
# [Text(0.625, 0.875, 'x[7] <= 10.5\ngini = 0.48\nsamples = 8799\nvalue = [3528, 5271]'),
#  Text(0.5, 0.625, 'x[8] <= 4125.5\ngini = 0.498\nsamples = 6653\nvalue = [3528, 3125]'),
#  Text(0.25, 0.375, 'x[5] <= 3.5\ngini = 0.493\nsamples = 2190\nvalue = [968, 1222]'),
#  Text(0.125, 0.125, 'gini = 0.342\nsamples = 525\nvalue = [115, 410]'),
#  Text(0.375, 0.125, 'gini = 0.5\nsamples = 1665\nvalue = [853, 812]'),
#  Text(0.75, 0.375, 'x[8] <= 5984.5\ngini = 0.489\nsamples = 4463\nvalue = [2560, 1903]'),
#  Text(0.625, 0.125, 'gini = 0.489\nsamples = 4432\nvalue = [2550, 1882]'),
#  Text(0.875, 0.125, 'gini = 0.437\nsamples = 31\nvalue = [10, 21]'),
#  Text(0.75, 0.625, 'gini = 0.0\nsamples = 2146\nvalue = [0, 2146]')]

# %%
#Let's plot the decision tree for test data.

tree.plot_tree(clf_gini.fit(X_test,y_test))
# Out:
# [Text(0.625, 0.875, 'x[7] <= 10.5\ngini = 0.485\nsamples = 2200\nvalue = [908, 1292]'),
#  Text(0.5, 0.625, 'x[8] <= 4010.5\ngini = 0.498\nsamples = 1699\nvalue = [908, 791]'),
#  Text(0.25, 0.375, 'x[8] <= 2004.0\ngini = 0.489\nsamples = 498\nvalue = [212, 286]'),
#  Text(0.125, 0.125, 'gini = 0.5\nsamples = 432\nvalue = [211, 221]'),
#  Text(0.375, 0.125, 'gini = 0.03\nsamples = 66\nvalue = [1, 65]'),
#  Text(0.75, 0.375, 'x[0] <= 1.5\ngini = 0.487\nsamples = 1201\nvalue = [696, 505]'),
#  Text(0.625, 0.125, 'gini = 0.459\nsamples = 205\nvalue = [132, 73]'),
#  Text(0.875, 0.125, 'gini = 0.491\nsamples = 996\nvalue = [564, 432]'),
#  Text(0.75, 0.625, 'gini = 0.0\nsamples = 501\nvalue = [0, 501]')]

# %% [markdown]
# Inference:
#
# - Accuracy of Training was 67.9623% and in testing is 67.4091% (for both criterion='gini'/'entropy') which means our model is an exact and Good Fit Model!
# - By observing the confusion matrix we can conclude there are 855 + 628 = 1483 correct prediction and 53 + 664 = 717 incorrect predictions
# - The area under the ROC curve score came to be 0.7138, which indicates moderate to good level of discrimination ability for your model.
# - The RMSE value came to be 0.5708, which indicates model's predictions are relatively accurate on average.
# - Average Cross Validation Score of the model came to be 64.2491, which indicates moderate model performance.
# - After optimizing Decision Tree Performance by tuning parameters, we can observe the metrics has slightly improved:
#     - Accuracy improved from 64.2273 to 67.4091 and is better than the previous decision tree model (without any parameter).
#     - Correct predictions has been improved from 1413 to 1413
#     - Incorrect predictions has been reduced from 787 to 717, it is better than Bernoulli Naive Bayes Model(908 incorrect predictions), LR model(805 incorrect predictions), KNN model(744 incorrect predictions) and SVM model(733 incorrect predictions)
#     - For class-0 the precision has decreased while the recall has increased and for class-1, precision has increased and recall has decreased
#     - Area under the ROC curve score improved from 0.6276 to 0.7138
#     - RMSE value has reduced from 0.5981 to 0.5708
#     - Cross validation score has improved from 63.4042 to 64.2491
#
# Let's try some ensemble algorithms inorder to improve the accuracy.

# %% [markdown]
# # Ensemble learning
#
# Ensemble learning helps improve machine learning results by combining several models. This approach allows the production of better predictive performance compared to a single model.
#
# - Advantage : Improvement in predictive accuracy.
# - Disadvantage : It is difficult to understand an ensemble of classifiers.
#
# The most common Ensemble learning are as follow:
# - Boosting (AdaBoost)
#     - AdaBoost is a good choice when you have a weak base learner and want to boost its performance.
#     - It can work well in binary classification, particularly when you have a diverse set of weak learners.
# - Bagging
#     - Bagging can be a good choice when you want to reduce variance and overfitting in your base model.
#     - It's a simple yet effective ensemble technique.
# - Random Forest
#     - Random Forest is a versatile and robust ensemble method that works well in a wide range of situations.
#     - It can handle both numerical and categorical data, is less prone to overfitting, and typically doesn't require extensive hyperparameter tuning.
#
#
# Approach
# - We will first use the three ensemble models (AdaBoost, Bagging, Random Forest) - [not required but for the understanding we will use all the three to compare the results]
# - Analyse the best performance model
# - Will try to reduce the tuning, bias, variance for the selected model
# - Lastly will evaluate all the models including the best chosen ensemble model by analysing the results

# %% [markdown]
# # Adaptive boosting algorithm (AdaBoost)
#
# The AdaBoost algorithm involves using very short (one-level) decision trees that are added sequentially to the ensemble.
# Each subsequent model attempts to correct the predictions made by the model before it in the sequence.
# This is achieved by weighing the training dataset to put more focus on training examples on which prior models made prediction errors.

# %%
#importing the AdaBoostClassifier from scikitlearn's ensemble class

from sklearn.ensemble import AdaBoostClassifier

# n_estimators defines maximum number of estimators at which boosting is terminated
# learning_rate defines the weight applied to each classifier at each boosting iteration

#adding parameters inorder to improve the overall accuracy
#We are using base model as Decision Tree because the accuracy so far was great for DT model

boost_model = AdaBoostClassifier(base_estimator= clf_gini, n_estimators = 100, learning_rate=1)

# fitting train data to the model
boost_model = boost_model.fit(X_train, y_train)

# %%
#Predict the train set result
y_train_boost = boost_model.predict(X_train)

#Check accuracy score for the train data
print('Training accuracy score with 100 decision-trees : {0:0.4f}'.format(accuracy_score(y_train,y_train_boost)*100))
# Out:
# Training accuracy score with 100 decision-trees : 79.0431

# %%
y_boost = boost_model.predict(X_test)

# Model Accuracy, how often is the classifier correct for test data
print('Testing accuracy score with 100 decision-trees: {0:0.4f}'.format(accuracy_score(y_test, y_boost)*100))
# Out:
# Testing accuracy score with 100 decision-trees: 64.7727

# %%
# Making the ROC AUC Score

roc_auc_score(y_test, y_boost)
# Out:
# 0.6423040465896537

# %%
#Let's calculate the rmse value

mse = mean_squared_error(y_test, y_boost)
rmse = sqrt(mse)
print("RMSE value :",rmse)
# Out:
# RMSE value : 0.5935256753272998

# %%
#Let's calculate the CrossValidation score for the model for 10 folds

scores = cross_val_score(boost_model, X, y, scoring='accuracy', cv = 10)

print("Cross Validation Scores: ", scores)
print("Average Cross Validation Score: ", scores.mean()*100)
print("Number of Cross Validation Scores used in Average: ", len(scores))
# Out:
# Cross Validation Scores:  [0.81636364 0.81545455 0.83181818 0.81909091 0.76636364 0.43181818
#  0.45636364 0.47       0.43       0.45404914]
# Average Cross Validation Score:  62.91321862850525
# Number of Cross Validation Scores used in Average:  10

# %%
#Confusion matrix

print('Confusion Matrix : \n', confusion_matrix(y_test, y_boost))
sns.heatmap(confusion_matrix(y_test, y_boost),fmt='.4g',annot=True)
# Out:
# Confusion Matrix :
#  [[555 353]
#  [422 870]]
# <Axes: >

# %%
#Classification Report

print('Classification Report : \n', classification_report(y_test, y_boost))
# Out:
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.57      0.61      0.59       908
#            1       0.71      0.67      0.69      1292
#
#     accuracy                           0.65      2200
#    macro avg       0.64      0.64      0.64      2200
# weighted avg       0.65      0.65      0.65      2200

# %% [markdown]
# Inference:
#
# - We have built the model by adding parameters and the Accuracy of Training was 79.0431% and in testing the accuracy is 64.7727%. There is a bit difference in the accuracies so can conclude that the model still has under-fitting problem and in not a good fit model.
# - By observing the confusion matrix we can conclude there are 555 + 870 = 1425 correct prediction and 353 + 422 = 775 incorrect predictions. The incorrect count is greater than the DT model.
# - The area under the ROC curve score came to be 0.6423, which indicates moderate discrimination ability of your model but leaves room for improvement.
# - The RMSE value came to be 0.5935, which indicates model's predictions are relatively accurate on average.
# - Average Cross Validation Score of the model came to be 62.9132, moderate model performance.
#
# Let's try another ensemble algorith using Decision tree as the base model.

# %% [markdown]
# # Bagging (Bootstrap Aggregating) Algorithm
#
# Bagging is used to deal with bias-variance trade-offs and reduces the variance of a prediction model.
# Bagging avoids overfitting of data and is used for both regression and classification models, specifically for decision tree algorithms.
# Bootstrapping is the method of randomly creating samples of data out of a population with replacement to estimate a population parameter.

# %%
#importing the BaggingClassifier from scikitlearn's ensemble class
#We are using base model as Decision Tree because the accuracy so far was great for DT model

from sklearn.ensemble import BaggingClassifier
bag_model = BaggingClassifier(base_estimator=clf_gini, n_estimators=100, random_state=0000, max_samples=1.0)

# n_estimators defines the number of base estimators in the ensemble 
# max_samples defines number of samples to draw from X to train each base estimator 

bag_model = bag_model.fit(X_train, y_train)

# %%
#Predict the train set result
y_train_pred = bag_model.predict(X_train)

#Check accuracy score for the train data
print('Training accuracy score with 100 decision-trees : {0:0.4f}'.format(accuracy_score(y_train,y_train_pred)*100))
# Out:
# Training accuracy score with 100 decision-trees : 67.8373

# %%
#Predict the test set result
y_bag = bag_model.predict(X_test)

#Check accuracy score for the train data
print('Testing accuracy score with 100 decision-trees : {0:0.4f}'.format(accuracy_score(y_test,y_bag)*100))
# Out:
# Testing accuracy score with 100 decision-trees : 67.3636

# %%
# Making the ROC AUC Score
roc_auc_score(y_test, y_bag)
# Out:
# 0.7137893645749512

# %%
#Let's calculate the rmse value

mse = mean_squared_error(y_test, y_bag)
rmse = sqrt(mse)
print("RMSE value :",rmse)
# Out:
# RMSE value : 0.5712824488496354

# %%
#Let's calculate the CrossValidation score for the model for 10 folds

scores = cross_val_score(bag_model, X, y, scoring='accuracy', cv = 10)

print("Cross Validation Scores: ", scores)
print("Average Cross Validation Score: ", scores.mean()*100)
print("Number of Cross Validation Scores used in Average: ", len(scores))
# Out:
# Cross Validation Scores:  [0.96272727 0.97       0.96454545 0.87727273 0.76272727 0.34818182
#  0.41       0.41454545 0.42       0.41674249]
# Average Cross Validation Score:  65.46742493175614
# Number of Cross Validation Scores used in Average:  10

# %%
#Confusion Matrix

print('Confusion Matrix : \n', confusion_matrix(y_test, y_bag))
sns.heatmap(confusion_matrix(y_test, y_bag),fmt='.4g',annot=True)
# Out:
# Confusion Matrix :
#  [[857  51]
#  [667 625]]
# <Axes: >

# %%
#Classification Report

print('Classification Report : \n', classification_report(y_test, y_bag))
# Out:
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.56      0.94      0.70       908
#            1       0.92      0.48      0.64      1292
#
#     accuracy                           0.67      2200
#    macro avg       0.74      0.71      0.67      2200
# weighted avg       0.78      0.67      0.66      2200

# %% [markdown]
# Inference:
#
# - We have built the model by adding parameters and the Accuracy of Training was 67.8373% and in testing the accuracy is 67.3636% which means our model is a good fit model.
# - By observing the confusion matrix we can conclude there are 555 + 869 = 1424 correct prediction and 353 + 423 = 776 incorrect predictions. The incorrect count is greater than the DT model.
# - The area under the ROC curve score came to be 0.7137 , which indicates moderate to good level of discrimination ability for your model.
# - The RMSE value came to be 0.5712, which indicates model's predictions are relatively accurate on average.
# - Average Cross Validation Score of the model came to be 65.4674, moderate model performance.
#
# The score and predication values are better than the past models. Let's try another popular ensemble algorithm using Decision tree as the base model and compare the results.

# %% [markdown]
# # Random Forest Algorithm
#
# - Random Forest is an ensemble technique that consists of multiple decision trees.
# - It combines their predictions to improve accuracy and generalization.
# - Random Forest is supervised learning technique.
# - The greater number of trees in the forest leads to higher accuracy and prevents the problem of overfitting.

# %%
#By default for Random forest algo it will take 100 decision trees, if we want to change to 20 then add n_estimator=20 after random_state
#Even by default the criterion is gini

from sklearn.ensemble import RandomForestClassifier

#instantiate the classifier
rfc = RandomForestClassifier(random_state=0)

#fit the train data to the model
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
#Predict the train set result
y_train_pred = rfc.predict(X_train)

#Check accuracy score for the train data
print('Training accuracy score with 100 decision-trees : {0:0.4f}'.format(accuracy_score(y_train,y_train_pred)*100))
# Out:
# Training accuracy score with 100 decision-trees : 100.0000

# %%
#Predict the Test set result
y_pred = rfc.predict(X_test)

#Check accuracy score for the test data
print('Model accuracy score with 100 decision-trees : {0:0.4f}'.format(accuracy_score(y_test,y_pred)*100))
# Out:
# Model accuracy score with 100 decision-trees : 64.4091

# %%
# Making the ROC AUC Score

roc_auc_score(y_test, y_pred)
# Out:
# 0.6480459213595013

# %%
#Let's calculate the rmse value

mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)
print("RMSE value :",rmse)
# Out:
# RMSE value : 0.5965811687516552

# %%
#Let's calculate the CrossValidation score for the model for 10 folds

scores = cross_val_score(rfc, X, y, scoring='accuracy', cv = 10)

print("Cross Validation Scores: ", scores)
print("Average Cross Validation Score: ", scores.mean()*100)
print("Number of Cross Validation Scores used in Average: ", len(scores))
# Out:
# Cross Validation Scores:  [0.84272727 0.83818182 0.83636364 0.83727273 0.76272727 0.42090909
#  0.45545455 0.44454545 0.43       0.44404004]
# Average Cross Validation Score:  63.122218545785415
# Number of Cross Validation Scores used in Average:  10

# %%
#Confusion Matrix

print('Confusion Matrix : \n', confusion_matrix(y_test, y_pred))
sns.heatmap(confusion_matrix(y_test, y_pred),fmt='.4g',annot=True)
# Out:
# Confusion Matrix :
#  [[609 299]
#  [484 808]]
# <Axes: >

# %%
#Classification Report

print('Classification Report : \n', classification_report(y_test,y_pred))
# Out:
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.56      0.67      0.61       908
#            1       0.73      0.63      0.67      1292
#
#     accuracy                           0.64      2200
#    macro avg       0.64      0.65      0.64      2200
# weighted avg       0.66      0.64      0.65      2200

# %% [markdown]
# Inference:
#
# - Accuracy of Training was 100% and in testing the accuracy is 64.409% which is a huge difference and we can conclude that the model has under-fitting problem, we can reduce this problem by changing the n_estimation, ccp_alpha , criterion this is called as hyper-tuning. To be more precise we will use GridsearchCV to find the best valued parameters.
# - By observing the confusion matrix we can conclude there are 609 + 808 = 1417 correct prediction and 299 + 484 = 783 incorrect predictions. The incorrect count is greater than the base model.
# - The area under the ROC curve score came to be 0.648, which indicates moderate discrimination ability of your model but leaves room for improvement.
# - The RMSE value came to be 0.5965, which indicates model's predictions are relatively accurate on average.
# - Average Cross Validation Score of the model came to be 63.1222, moderate model performance.
#
# Let's improve this accuracy by tuning the parameters using Gridsearch.

# %%
#Let’s do hyperparameter tuning for Random Forest using GridSearch 

rf = RandomForestClassifier(random_state=0, n_jobs=-1)   #Here we are passing range for variour parameters
params = {
    'max_depth': [2,3,5,10,20],
    'min_samples_leaf': [5,10,20,50,100,200],
    'n_estimators': [10,25,30,50,100,200]
}

# Instantiate the grid search model
grid_search = GridSearchCV(estimator=rf,
                           param_grid=params,
                           cv = 4,
                           n_jobs=-1, verbose=1, scoring="accuracy")

# %%
#Fitting train dataset to the new model(grid_search)

grid_search.fit(X_train, y_train)
# Out:
# Fitting 4 folds for each of 180 candidates, totalling 720 fits
# GridSearchCV(cv=4, estimator=RandomForestClassifier(n_jobs=-1, random_state=0),
#              n_jobs=-1,
#              param_grid={'max_depth': [2, 3, 5, 10, 20],
#                          'min_samples_leaf': [5, 10, 20, 50, 100, 200],
#                          'n_estimators': [10, 25, 30, 50, 100, 200]},
#              scoring='accuracy', verbose=1)

# %%
#Checking the best score by using GridSearchCV algo

grid_search.best_score_
# Out:
# 0.6843960064492125

# %%
#Checking the best suited parameters

grid_search.best_estimator_
# Out:
# RandomForestClassifier(max_depth=5, min_samples_leaf=20, n_estimators=200,
#                        n_jobs=-1, random_state=0)

# %%
#Let's implement the model with best_estimator_ parameters and fit the train data to the model

RFclassifier = RandomForestClassifier(max_depth=5, min_samples_leaf=20, n_estimators=200, n_jobs=-1, random_state=0)
RFclassifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, min_samples_leaf=20, n_estimators=200,
#                        n_jobs=-1, random_state=0)

# %%
#Predict the Test set result
y_pred_train = RFclassifier.predict(X_train)

#Check accuracy score for the test data
print('Model accuracy score with 100 decision-trees : {0:0.4f}'.format(accuracy_score(y_train,y_pred_train)*100))
# Out:
# Model accuracy score with 100 decision-trees : 69.1556

# %%
#Predict the Test set result
y_pred = RFclassifier.predict(X_test)

#Check accuracy score for the test data
print('Model accuracy score with 100 decision-trees : {0:0.4f}'.format(accuracy_score(y_test,y_pred)*100))
# Out:
# Model accuracy score with 100 decision-trees : 68.2273

# %%
# Making the ROC AUC Score

roc_auc_score(y_test, y_pred)
# Out:
# 0.71819635575074

# %%
#Let's calculate the rmse value

mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)
print("RMSE value :",rmse)
# Out:
# RMSE value : 0.5636730193359203

# %%
#Let's calculate the CrossValidation score for the model for 10 folds

scores = cross_val_score(RFclassifier, X, y, scoring='accuracy', cv = 10)

print("Cross Validation Scores: ", scores)
print("Average Cross Validation Score: ", scores.mean()*100)
print("Number of Cross Validation Scores used in Average: ", len(scores))
# Out:
# Cross Validation Scores:  [0.93818182 0.96       0.92727273 0.90727273 0.80454545 0.39363636
#  0.41363636 0.41272727 0.40909091 0.39945405]
# Average Cross Validation Score:  65.65817685499213
# Number of Cross Validation Scores used in Average:  10

# %%
#Confusion Matrix

print('Confusion Matrix : \n', confusion_matrix(y_test, y_pred))
sns.heatmap(confusion_matrix(y_test, y_pred),fmt='.4g',annot=True)
# Out:
# Confusion Matrix :
#  [[839  69]
#  [630 662]]
# <Axes: >

# %%
rfc.feature_importances_
# Out:
# array([0.05915634, 0.03436936, 0.05576351, 0.05698234, 0.18595119,
#        0.05179374, 0.03192712, 0.22646204, 0.29759436])

# %%
#Classification Report

print('Classification Report : \n', classification_report(y_test, y_pred))
# Out:
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.57      0.92      0.71       908
#            1       0.91      0.51      0.65      1292
#
#     accuracy                           0.68      2200
#    macro avg       0.74      0.72      0.68      2200
# weighted avg       0.77      0.68      0.68      2200

# %% [markdown]
# Inference:
#
# - Accuracy of Training was 69.1556% and in testing is 68.2273% which means our model is an exact and Good Fit Model!
# - By observing the confusion matrix we can conclude there are 839 + 662 = 1501 correct prediction and 69 + 630 = 699 incorrect predictions
# - The area under the ROC curve score came to be 0.7181, which indicates moderate to good level of discrimination ability for your model.
# - The RMSE value came to be 0.5636, which indicates model's predictions are relatively accurate on average.
# - Average Cross Validation Score of the model came to be 65.6581, which indicates moderate model performance.
# - After optimizing the model by tuning parameters, we can observe the metrics has slightly improved:
#     - Accuracy improved from 64.4091 to 68.2273 and is better than the previous models.
#     - Correct predictions has been improved from 1417 to 1501 and is better than the previous models.
#     - Incorrect predictions has been reduced from 783 to 699, it is better than Bernoulli Naive Bayes Model(908 incorrect predictions), LR model(805 incorrect predictions), KNN model(744 incorrect predictions), SVM model(733 incorrect predictions) and DT model(717 incorrect predictions)
#     - For class-0 the precision has increased while the recall has increased and for class-1, precision has increased and recall has decreased. The f1-score is much better than the previous models
#     - Area under the ROC curve score improved from 0.648 to 0.7181. It is the highest among all the models.
#     - RMSE value has reduced from 0.5965 to 0.5636 which is the lowest error causing model till now.
#     - Cross validation score has improved from 63.1222 to 65.6581

# %% [markdown]
# # Conclusion
#
# After analysing all the models, we can conclude:
#
# - Out of all the models the Random Forest algorithm with base model as Decision tree gives the best result.
# - The accuracy is optimised.
# - Better and clearer predictions with highest precision, recall and f1-score.
# - Minimum RMSE value
# - High Cross Validation score
